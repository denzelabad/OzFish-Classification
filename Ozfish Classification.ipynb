# %% [markdown]
# # OzFish Classification Project
#
# This project aims to use a Convolutional Neural Network to try and correctly classify various species of Australian fish in images obtained from underwater videos.
# The original OzFish dataset used in this project has over 80,823 images of fish derived from Baited Underwater Video Stations, featuring 496 different species of Australian fish.

# %% [markdown]
# ### Import Packages

# %%
import os 
from os import listdir # Used for acquiring filenames in image folder
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.model_selection import train_test_split
import tensorflow as tf
import tensorflow_addons as tfa # For focal loss function
from tensorflow import keras
from tensorflow.keras import models, layers
from sklearn.metrics import classification_report # For classification report

# %% [markdown]
# ### Fix Files

# %% [markdown]
# All downloaded files came with a naming error, resulting in the wrong png extension, for example: '.png-27871'.
# All files should be converted back into a regular .png extension:

# %%
for image_file in listdir('crops'):
    split = image_file.split('.png')
    os.rename('crops/' + image_file, 'crops/' + split[0] + '.png')

# %% [markdown]
# ### Preprocess and Clean Dataset

# %% [markdown]
# The OzFish dataset provides an associated metadata file for the images, containing information such as species, family and genus for each identified fish.
# We'll combine the metadata and the filepaths for each image in one dataframe:

# %%
metadata = pd.read_csv('crop_metadata.csv', index_col = 0)
metadata['file_name'] = 'crops/' + metadata['file_name'].astype(str) # Add filepath to each filename
metadata.head()
# Out:
#                                           file_name        family       genus  \
# uid
# 1      crops/A000001_L.avi.5107.806.371.922.448.png      Scaridae   Chlorurus
# 2    crops/A000001_R.avi.4902.1388.355.1508.435.png      Scaridae   Chlorurus
# 3      crops/A000001_L.avi.5174.912.280.994.335.png      Scaridae   Chlorurus
# 4    crops/A000001_R.avi.4969.1600.255.1682.310.png      Scaridae   Chlorurus
# 5      crops/A000001_L.avi.5194.811.472.979.584.png  Acanthuridae  Acanthurus
#
#             species
# uid
# 1    capistratoides
# 2    capistratoides
# 3    capistratoides
# 4    capistratoides
# 5      leucocheilus

# %%
metadata['species'].nunique()
# Out:
# 496

# %%
metadata['species'].value_counts()
# Out:
# punctulatus    6095
# digramma       3172
# atkinsoni      2635
# sebae          2338
# lutescens      2007
#                ...
# nigripinnis       2
# octotaenia        2
# tiere             2
# taeniatus         2
# valentini         2
# Name: species, Length: 496, dtype: int64

# %% [markdown]
# We can see that there is quite a substantial class imbalance in this dataset; the most frequent class consisting of 6095 images while the least frequent class consisting of only 2. It may be ideal to simply remove species that have too few images as they would otherwise have a considerable impact on the model's performance.
#
# We'll set a threshold for classes needing at least 100 images to be included in training and testing the model.

# %%
freq = pd.DataFrame(metadata['species'].value_counts()) # Dataframe containing species counts
freq.reset_index(inplace = True)
freq.rename(columns = {'index': 'Species', 'species': 'Count'}, inplace = True)

i = 0
for element in freq['Count']:
    if element < 100:
        i += 1
print('There are ' + str(i) + ' species that have less than 100 samples')
# Out:
# There are 338 species that have less than 100 samples

# %% [markdown]
# We'll now remove the classes with less than 100 samples:

# %%
i = 0
filtered = [] # Contains species with >= 100 samples
for i in range(len(freq)):
    if freq['Count'][i] >= 100:
        i += 1
        filtered.append(freq['Species'][i])
        
cols = ['file_name', 'species']
fish = metadata[cols] # Remove unnecessary columns
fish = fish[fish['species'].isin(filtered)] # Filter species
fish = fish.sample(frac=1).reset_index(drop = True) # Shuffle images
fish.to_csv('ozfish_clean_dataset') # Save to csv

# %%
fish['species'].nunique()
# Out:
# 158

# %%
fish.head()
# Out:
#                                         file_name        species
# 0   crops/G000110_R.avi.14088.619.313.745.397.png  flavolineatus
# 1  crops/E000570_L.MP4.29335.990.296.1824.852.png          sebae
# 2   crops/G000374_R.avi.27649.145.250.525.504.png          ravus
# 3   crops/G000030_R.avi.108983.29.351.125.415.png   sexfasciatus
# 4      crops/E000256_R.MP4.16694.8.32.407.298.png   multinotatus

# %%
fish.shape
# Out:
# (66212, 2)

# %% [markdown]
# We're now left with 66,212 images and 158 unique classes.
#
# To gain a better understanding of what our data looks like, we'll sample a few images and display them:

# %%
def load_images(df):
    rows = 6
    columns = 3
    fig = plt.figure(figsize=(12,12))
    for i in range(1, rows*columns+1):
        fig.add_subplot(rows,columns,i)
        plt.axis("off")
        plt.title(df['species'][i])
        plt.imshow(plt.imread(df['file_name'][i]))
    plt.tight_layout()
    plt.show()
    
load_images(fish)

# %% [markdown]
# Looking at the samples displayed above, we can see there is some disparity in the clarity of the images. Some fish are quite clearly presented in the image, while some are much harder to see. There are many photos in the dataset where irrelevant objects (such as pipes or coral) are covering parts of the fish, and even photos that contain multiple, overlapping fish. These will undoubtedly have an impact on the model's performance, but filtering out these images would be beyond the scope of this project so they'll be left as they are.

# %% [markdown]
# ### Splitting Data

# %% [markdown]
# The data will be split into 70% for training, 20% for testing and 10% for validation.

# %%
train, test = train_test_split(fish, train_size = 0.8, random_state = 22)
train, valid = train_test_split(train, test_size = 0.1, random_state = 22) # Sample 10% validation data from training data

# %%
train.shape
# Out:
# (47672, 2)

# %%
test.shape
# Out:
# (13243, 2)

# %%
valid.shape
# Out:
# (5297, 2)

# %% [markdown]
# ### Data Augmentation

# %% [markdown]
# As some species in the training dataset may have relatively few images, it may be necessary to generate more samples via data augmentation. This will give the model a larger number of samples for each species to train with.
# We'll apply the following augmentations:
# - Randomly rotated +- 5 degrees
# - Shift vertically by factor of 0.1
# - Shift horizontally by factor of 0.1
# - Sheared by factor of 0.1
# - Randomly zoom in range [0.9, 1.1]
# - Points outside boundaries filled based on nearest point
# - Rescale image with 1/255 factor

# %%
train_generator = tf.keras.preprocessing.image.ImageDataGenerator(rotation_range = 5,
                                                                  width_shift_range = 0.1,
                                                                  height_shift_range = 0.1,
                                                                  shear_range = 0.1,
                                                                  zoom_range = 0.1,
                                                                  horizontal_flip = True,
                                                                  fill_mode = 'nearest',
                                                                  rescale = 1./255)
                                                                 
test_generator = tf.keras.preprocessing.image.ImageDataGenerator(rescale = 1./255) # Test data only rescaled

train_img = train_generator.flow_from_dataframe(
    dataframe = train,
    x_col = 'file_name',
    y_col = 'species',
    target_size = (128,128),
    color_mode = 'rgb',
    class_mode = 'categorical',
    batch_size = 32,
    shuffle = True,
    seed = 22
)

val_img = train_generator.flow_from_dataframe(
    dataframe = valid,
    x_col = 'file_name',
    y_col = 'species',
    target_size = (128,128),
    color_mode = 'rgb',
    class_mode = 'categorical',
    batch_size = 32,
    shuffle = True,
    seed = 22
)

test_img = test_generator.flow_from_dataframe(
    dataframe = test,
    x_col = 'file_name', 
    y_col = 'species',
    target_size = (128,128),
    color_mode = 'rgb',
    class_mode = 'categorical',
    batch_size = 32,
    shuffle = False
)
# Out:
# Found 47672 validated image filenames belonging to 158 classes.
# Found 5297 validated image filenames belonging to 158 classes.
# Found 13243 validated image filenames belonging to 158 classes.

# %% [markdown]
# ### Creating the CNN Architecture

# %% [markdown]
# Using the MiniVGGNet implementation as a foundation, we'll begin designing the architecture for the CNN.
# The following table outlines the general MiniVGGNet architecture:
# <img src='img/minivggnet.png' align='center' width=400/>
# Now we'll implement an altered version of this network architecture that works best with our data:

# %%
num_classes = fish['species'].nunique()

# %%
cnn_model = models.Sequential()

cnn_model.add(layers.Conv2D(32, (3,3), padding = 'same', activation = 'relu', input_shape = (128, 128, 3)))
cnn_model.add(layers.BatchNormalization(momentum = 0.9))
cnn_model.add(layers.Conv2D(32, (3,3), padding = 'same', activation = 'relu'))
cnn_model.add(layers.BatchNormalization(momentum = 0.9))
cnn_model.add(layers.MaxPool2D(pool_size = (2,2)))


cnn_model.add(layers.Conv2D(64, (3,3), padding = 'same', activation = 'relu'))
cnn_model.add(layers.BatchNormalization(momentum = 0.9))
cnn_model.add(layers.Conv2D(64, (3,3), padding = 'same', activation = 'relu'))
cnn_model.add(layers.MaxPool2D(pool_size = (2,2)))


cnn_model.add(layers.Conv2D(128, (3,3), padding = 'same', activation = 'relu'))
cnn_model.add(layers.BatchNormalization(momentum = 0.9))
cnn_model.add(layers.Conv2D(128, (3,3), padding = 'same', activation = 'relu'))
cnn_model.add(layers.MaxPool2D(pool_size = (2,2)))
cnn_model.add(layers.Dropout(rate = 0.5))

cnn_model.add(layers.Conv2D(256, (3,3), padding = 'same', activation = 'relu'))
cnn_model.add(layers.BatchNormalization(momentum = 0.9))
cnn_model.add(layers.Conv2D(256, (3,3), padding = 'same', activation = 'relu'))
cnn_model.add(layers.MaxPool2D(pool_size = (2,2)))


cnn_model.add(layers.Flatten())
cnn_model.add(layers.Dense(512, activation = 'relu'))
cnn_model.add(layers.BatchNormalization(momentum = 0.9))
cnn_model.add(layers.Dropout(rate = 0.5))
cnn_model.add(layers.Dense(num_classes, activation = 'softmax'))

# %%
cnn_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 128, 128, 32)      896
# _________________________________________________________________
# batch_normalization (BatchNo (None, 128, 128, 32)      128
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 128, 128, 32)      9248
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 128, 128, 32)      128
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 64, 64, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 64, 64, 64)        18496
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 64, 64, 64)        256
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 64, 64, 64)        36928
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 32, 32, 64)        0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 32, 32, 128)       73856
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 32, 32, 128)       512
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 32, 32, 128)       147584
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 16, 16, 128)       0
# _________________________________________________________________
# dropout (Dropout)            (None, 16, 16, 128)       0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 16, 16, 256)       295168
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 16, 16, 256)       1024
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 16, 16, 256)       590080
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 8, 8, 256)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 16384)             0
# _________________________________________________________________
# dense (Dense)                (None, 512)               8389120
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 512)               2048
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 158)               81054
# =================================================================
# Total params: 9,646,526
# Trainable params: 9,644,478
# Non-trainable params: 2,048
# _________________________________________________________________

# %% [markdown]
# ### Compiling and Training the CNN

# %% [markdown]
# Now that the model's architecture has been created, it's time to compile the model and begin training.
# The focal loss function was used as it performs quite well with datasets containing a large class imbalance. We'll also use the Adam optimizer with a learning rate of 0.001.

# %%
adam = tf.keras.optimizers.Adam(learning_rate = 0.001)
cnn_model.compile(optimizer = adam, loss = tfa.losses.SigmoidFocalCrossEntropy(), metrics = ['accuracy'])

history = cnn_model.fit(
    train_img, batch_size = 32,
    epochs = 70,
    validation_data = val_img,
    callbacks = [
        tf.keras.callbacks.EarlyStopping(
            monitor = 'val_loss',
            patience = 8, # Stop after 8 epochs if validation loss does not increase
            restore_best_weights = True
        )
    ]
)
# Out:
# Epoch 1/70
# 1490/1490 [==============================] - 199s 131ms/step - loss: 0.9495 - accuracy: 0.1533 - val_loss: 0.7324 - val_accuracy: 0.2515
# Epoch 2/70
# 1490/1490 [==============================] - 175s 117ms/step - loss: 0.7000 - accuracy: 0.2838 - val_loss: 0.6041 - val_accuracy: 0.3708
# Epoch 3/70
# 1490/1490 [==============================] - 175s 118ms/step - loss: 0.6037 - accuracy: 0.3538 - val_loss: 0.5590 - val_accuracy: 0.4091
# Epoch 4/70
# 1490/1490 [==============================] - 176s 118ms/step - loss: 0.5315 - accuracy: 0.4111 - val_loss: 0.4504 - val_accuracy: 0.4850
# Epoch 5/70
# 1490/1490 [==============================] - 176s 118ms/step - loss: 0.4909 - accuracy: 0.4445 - val_loss: 0.4197 - val_accuracy: 0.5195
# Epoch 6/70
# 1490/1490 [==============================] - 176s 118ms/step - loss: 0.4445 - accuracy: 0.4900 - val_loss: 0.3790 - val_accuracy: 0.5548
# Epoch 7/70
# 1490/1490 [==============================] - 176s 118ms/step - loss: 0.4125 - accuracy: 0.5218 - val_loss: 0.4552 - val_accuracy: 0.4880
# Epoch 8/70
# 1490/1490 [==============================] - 176s 118ms/step - loss: 0
# 1490/1490 [==============================] - 189s 127ms/step - loss: 0.1301 - accuracy: 0.8236 - val_loss: 0.1855 - val_accuracy: 0.7946
# Epoch 56/70
# 1490/1490 [==============================] - 191s 128ms/step - loss: 0.1292 - accuracy: 0.8247 - val_loss: 0.1907 - val_accuracy: 0.7799
# Epoch 57/70
# 1490/1490 [==============================] - 191s 128ms/step - loss: 0.1268 - accuracy: 0.8261 - val_loss: 0.1837 - val_accuracy: 0.7886

# %% [markdown]
# ### Evaluate Model Training

# %% [markdown]
# To see how well the model learned throughout each epoch, we'll create a few plots that highlight its accuracy and loss during training:

# %%
plt.plot(history.history["accuracy"], label="train_acc")
plt.plot(history.history["val_accuracy"], label="val_acc")
plt.title('Accuracy Plot')
plt.xlabel("epochs")
plt.ylabel("accuracy")
plt.legend()
plt.show()

# %%
plt.plot(history.history["loss"], label="train_loss")
plt.plot(history.history["val_loss"], label="val_loss")
plt.title('Loss Plot')
plt.xlabel("epochs")
plt.ylabel("loss")
plt.legend()
plt.show()

# %% [markdown]
# ### Model Results and Performance

# %% [markdown]
# In order to see how well our model performs, we'll use it to predict the classes of all the images in the testing dataset:

# %%
result = cnn_model.evaluate(test_img)
print('Test Loss: {:.5f}'.format(result[0]))
print('Test Accuracy: {:.2f}%'.format(result[1] * 100))
# Out:
# 414/414 [==============================] - 18s 42ms/step - loss: 0.1583 - accuracy: 0.8182
# Test Loss: 0.15829
# Test Accuracy: 81.82%

# %% [markdown]
# The model performed quite well with an 81.82% accuracy in predicting images in the test set, along with a loss of 0.158. This model saw an increase of almost 27% in its test accuracy from the basic MiniVGGNet architecture, as the basic one achieved a test accuracy of only 55%.
#
# As this was a very imbalanced class dataset, what we need to evaluate is the model's performance for predicting specific fish species. To do this, we'll generate a classification report:

# %%
# Create array containing predicted labels for each image in the test set
pred_test = cnn_model.predict(test_img) # Dataframe containing label predictions of each image
pred_test = np.argmax(pred_test, axis = 1,) # Get the row indexes of the most likely labels for each image
labs = dict((x,y) for y,x in train_img.class_indices.items()) # Reverse key:value positions in dictionary
pred_test = [labs[i] for i in pred_test]
actual = list(test['species']) # Get true labels
print(classification_report(actual, pred_test))
# Out:
#                   precision    recall  f1-score   support
#
#        aculeatus       0.88      0.96      0.92        24
#    albimarginata       0.64      0.64      0.64        11
#    amblycephalum       0.79      0.71      0.75        97
#    amblyrhynchos       0.71      0.98      0.83        53
#      amboinensis       0.82      0.56      0.67        55
#        annulatus       0.65      0.51      0.57       118
#        areolatus       0.91      0.81      0.86       219
#        argenteus       0.72      0.72      0.72       131
#            argus       0.69      0.64      0.67        28
#          aruanus       0.85      0.97      0.91        36
#         assarius       0.95      1.00      0.97        37
#        atkinsoni       0.88      0.94      0.91       544
#   atripectoralis       0.69      0.83      0.75        24
#           auriga       0.99      0.96      0.97        74
#           aygula       0.85      0.58      0.69        59
#      bandanensis       0.56      0.20      0.29        25
#    barberinoides       0.92      0.84      0.88        43
#      bengalensis       0.91      0.74      0.82        43
#          bicolor       0.88      0.71      0.79        21
#        bilineata       0.94      0.93      0.94        55
#        bilobatus       0.63      0.81      0.71        21
#      bimaculatus       0.36      0.13      0.19        31
#            bohar       0.90      0.92      0.91        86
#     brevirostris       0.78      0.81      0.80        43
# caeruleopinnatus       0.80      0.83      0.81        42
#   capistratoides       0.73      0.67      0.70        33
#     carponotatus       0.76      0.91      0.83        53
#        nebulosus       0.76      0.55      0.63       181
#     nematophorus       0.83      0.48      0.61        31
#            niger       0.90      0.95      0.92       353
#        nigricans       0.78      0.60      0.68        53
#   novaezelandiae       0.95      0.98      0.96        53
#           obesus       0.94      0.81      0.87        36
#         obtusata       0.85      0.87      0.86        38
#    obtusirostris       0.81      0.71      0.76        31
#        olivaceus       0.65      0.65      0.65        86
#     orthogrammus       0.85      0.81      0.83        77
#           pictum       0.74      0.61      0.67        28
#         plebeius       0.98      0.95      0.96        42
#     pleurostigma       0.83      0.73      0.77        33
#          porosus       0.83      0.86      0.84       194
#    prasiognathos       0.49      0.68      0.57        73
#            qenie       0.92      1.00      0.96        23
#            ravus       0.65      0.45      0.53        29
#      reticulatus       0.87      0.65      0.74        40
#      rhodochrous       0.67      0.25      0.36        24
#        rivulatus       0.73      0.71      0.72       124
# rubrioperculatus       0.81      0.87      0.84       378
#   rubroviolaceus       0.86      0.36      0.51        33
#       sceleratus       0.95      0.87      0.91        67
#        schlegeli       0.54      0.42      0.47        62
#     schoenleinii       0.58      0.50      0.54        30
#           scopas       0.60      0.60      0.60        25
#            sebae       0.91      0.98      0.95       451
#   semicirculatus       0.79      0.71      0.75        21
#         severnsi       0.54      0.82      0.65       103
#     sexfasciatus       0.97      0.99      0.98       118
#          solatus       0.86      0.80      0.83        45
#         sordidus       0.54      0.60      0.57       107
#              sp1       0.56      0.28      0.37        18
#             sp10       0.69      0.51      0.59       165
#              sp3       0.49      0.50      0.49        40
#        speciosus       0.89      0.77      0.82        52
#         spilurus       0.87      0.91      0.89        45
#              spp       0.75      0.84      0.79       351
#        stellatus       0.94      0.90      0.92       102
#         striatus       0.67      0.73      0.70       139
#       temminckii       0.68      0.80      0.74       203
#            teres       1.00      0.90      0.95        48
#       thynnoides       0.86      0.97      0.91        32
#             tile       0.93      0.95      0.94       170
#     trifascialis       0.93      0.84      0.89        32
#     trifasciatus       0.85      0.71      0.77        24
#       trilobatus       0.80      0.38      0.52        21
#     trimaculatus       0.88      0.70      0.78       122
#       triostegus       0.98      0.97      0.97       208
#       ulietensis       1.00      0.85      0.92        20
#      undosquamis       0.84      0.84      0.84        63
#        unicornis       0.82      0.87      0.84        53
#       vaigiensis       0.75      0.88      0.81        64
#           vaiuli       0.69      0.64      0.67        28
#             vari       0.95      0.94      0.94        94
#       variegatus       0.80      0.78      0.79        55
#           varius       0.92      0.35      0.51        34
#            vidua       0.86      0.83      0.85        30
#          viridis       0.92      0.87      0.89       141
#            vitta       0.90      0.92      0.91       348
#           weberi       0.92      0.80      0.85        59
#       xenochrous       1.00      0.85      0.92        47
#       zeylonicus       0.87      0.69      0.77        39
#
#         accuracy                           0.82     13243
#        macro avg       0.80      0.74      0.76     13243
#     weighted avg       0.82      0.82      0.81     13243

# %%
cnn_model.save('ozfish_cnn') # Save the model
# Out:
# INFO:tensorflow:Assets written to: ozfish_cnn\assets
